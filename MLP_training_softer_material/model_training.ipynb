# %%
# import necessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt
import joblib

device = 'cuda' if torch.cuda.is_available() else 'cpu'

def seed_all(seed=0):
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# %%
# Load features and split and scale the dataset
df = pd.read_csv("../features_output_softer_material.csv")
X = df.drop(columns=["Label"]).values
y = df["Label"].values

# === Split & scale ===
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

joblib.dump(scaler, "scaler.joblib")
print("✅ Saved scaler to scaler.joblib")
# Out:
# ✅ Saved scaler to scaler.joblib

# %%
print(X_test_scaled.shape, y_test.shape)
print(X_train_scaled.shape, y_train.shape)
# print first 10 rows of the test set
print(X_test_scaled[:1])
print(y_test[:40])
# Out:
# (40, 36) (40,)
# (160, 36) (160,)
# [[ 0.55828826 -0.74009879 -1.04191126  1.25220871 -0.36004461 -0.36179003
#   -1.19446512  0.08155377 -0.10835789  0.10835789  0.54010705 -0.69059759
#    1.105964    0.49685516 -0.95075554  1.18836195 -0.58128253 -0.13788186
#   -0.37141605  0.02072616 -0.54896197  0.40724909 -0.58230714  0.8168328
#   -0.67736618 -0.53026872 -0.68492455  0.22435428 -0.5860555  -0.3004795
#   -0.58932878 -0.89363172 -0.74754843 -0.15041723 -0.94888535 -0.81060237]]
# [0 2 0 1 3 3 3 2 2 2 0 2 1 3 2 0 0 1 3 0 1 1 1 3 1 1 0 0 1 3 0 3 0 1 2 2 3
#  2 2 3]

# %%
# Convert to tensors ===
X_train_tensor = torch.tensor(X_train_scaled, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=16, shuffle=True)
test_loader = DataLoader(TensorDataset(X_test_tensor, y_test_tensor), batch_size=16, shuffle=False)

# %%
class DeepMLP(nn.Module):
    def __init__(self, input_size=36, hidden_sizes=[128, 64, 32], output_size=8, p_dropout=0.3, device='cpu'):
        super().__init__()
        self.device = device

        layers = []
        in_feats = input_size
        for h in hidden_sizes:
            layers += [
                nn.Linear(in_feats, h),
                nn.BatchNorm1d(h),
                nn.ReLU(),
                nn.Dropout(p_dropout)
            ]
            in_feats = h
        layers.append(nn.Linear(in_feats, output_size))
        self.net = nn.Sequential(*layers)
        self.to(device=device)
        self.lossfn = nn.CrossEntropyLoss()
        

    def forward(self, x):
        return self.net(x)
    
    def Train(self, epochs, optimizer, loader_train, loader_test, verbose=True, patience=10):
        best_loss = float('inf')  # Initialize best loss
        self.loss_train_log = []
        self.loss_test_log = []
        epoch_no_improvement = 0  # Counter for early stopping
        for epoch in range(epochs):
            self.train()
            for x, y in loader_train:
                x = x.to(self.device)
                y = y.to(self.device)
                optimizer.zero_grad()
                y_pred = self.forward(x)
                loss = self.lossfn(y_pred, y)
                loss.backward()
                optimizer.step()
            loss_train = self.evaluate(loader_train)
            loss_test = self.evaluate(loader_test)
            self.loss_train_log.append(loss_train)
            self.loss_test_log.append(loss_test)
            # Save the best model
            if loss_test < best_loss:
                epoch_no_improvement = 0      
                best_loss = loss_test
                torch.save(self.state_dict(), 'best_model.pth')  # 🔐 Save best model
                print(f"Best model saved with loss: {best_loss:.4f} at {epoch+1}")
            else:
                epoch_no_improvement += 1
                if epoch_no_improvement >= patience:
                    print(f"Early stopping at epoch {epoch+1} with no improvement.")
                    break
                
            if verbose:
                print(f"Epoch {epoch+1}/{epochs} | Train Loss: {self.loss_train_log[-1]:.4f} | Test Loss: {self.loss_test_log[-1]:.4f}")

    def evaluate(self, loader):
        self.eval()
        total_loss = 0
        with torch.no_grad():
            for x, y in loader:
                x = x.to(self.device)
                y = y.to(self.device)
                y_pred = self.forward(x)
                loss = self.lossfn(y_pred, y)
                total_loss += loss.item()
        return total_loss / len(loader)

# %%
model = DeepMLP(input_size=36, hidden_sizes=[256,128,64,32], output_size=8, p_dropout=0.3, device=device)
# also be extra‐sure you didn’t accidentally create it on CPU:
model = model.to(device)
print(model.device)
optimizer = torch.optim.Adam(model.parameters(), lr=2e-4, weight_decay=2e-5)
model.Train(epochs=200, optimizer=optimizer, loader_train=train_loader, loader_test=test_loader, patience=15)
# Out:
# cuda
# Best model saved with loss: 2.0990 at 1
# Epoch 1/200 | Train Loss: 2.0997 | Test Loss: 2.0990
# Best model saved with loss: 2.0477 at 2
# Epoch 2/200 | Train Loss: 2.0315 | Test Loss: 2.0477
# Best model saved with loss: 1.9524 at 3
# Epoch 3/200 | Train Loss: 1.9199 | Test Loss: 1.9524
# Best model saved with loss: 1.8716 at 4
# Epoch 4/200 | Train Loss: 1.8239 | Test Loss: 1.8716
# Best model saved with loss: 1.8108 at 5
# Epoch 5/200 | Train Loss: 1.7513 | Test Loss: 1.8108
# Best model saved with loss: 1.7587 at 6
# Epoch 6/200 | Train Loss: 1.6975 | Test Loss: 1.7587
# Best model saved with loss: 1.7057 at 7
# Epoch 7/200 | Train Loss: 1.6403 | Test Loss: 1.7057
# Best model saved with loss: 1.6894 at 8
# Epoch 8/200 | Train Loss: 1.6098 | Test Loss: 1.6894
# Best model saved with loss: 1.6212 at 9
# Epoch 9/200 | Train Loss: 1.5327 | Test Loss: 1.6212
# Best model saved with loss: 1.5884 at 10
# Epoch 10/200 | Train Loss: 1.4957 | Test Loss: 1.5884
# Best model saved with loss: 1.5437 at 11
# Epoch 11/200 | Train Loss: 1.4460 | Test Loss: 1.5437
# Best model saved with loss: 1.5068 at 12
# Epoch 12/200 | Train Loss: 1.4024 | Test Loss: 1.5068
# Best model saved with loss: 1.4577 at 13
# Epoch 13/200 | Train Loss: 1.3459 | Test Loss: 1.4577
# Best model saved with loss: 1.4268 at 14
# Epoch 14/200 | Train Loss: 1.3141 | Test Loss: 1.4268
# Best model saved with loss: 1.3325 at 15
# Epoch 15/200 | Train Loss: 1.2215 | Test Loss: 1.3325
# Best model saved with loss: 1.2850 at 16
# Epoch 16/200 | Train Loss: 1.1710 | Test Loss: 1.2850
# Best model saved with loss: 1.2561 at 17
# Epoch 17/200 | Train Loss: 1.1409 | Test Loss: 1.2561
# Best model saved with loss: 1.2235 at 18
# Epoch 18/200 | Train Loss: 1.1105 | Test Loss: 1.2235
# Best model saved with loss: 1.1795 at 19
# Epoch 19/200 | Train Loss: 1.0660 | Test Loss: 1.1795
# Best model saved with loss: 1.1348 at 20
# Epoch 20/200 | Train Loss: 1.0212 | Test Loss: 1.1348
# Best model saved with loss: 1.1037 at 21
# Epoch 21/200 | Train Loss: 0.9967 | Test Loss: 1.1037
# Best model saved with loss: 1.0555 at 22
# Epoch 22/200 | Train Loss: 0.9524 | Test Loss: 1.0555
# Best model saved with loss: 1.0291 at 23
# Epoch 23/200 | Train Loss: 0.9332 | Test Loss: 1.0291
# Best model saved with loss: 0.9951 at 24
# Epoch 24/200 | Train Loss: 0.8980 | Test Loss: 0.9951
# Best model saved with loss: 0.9540 at 25
# Epoch 25/200 | Train Loss: 0.8550 | Test Loss: 0.9540
# Best model saved with loss: 0.9083 at 26
# Epoch 26/200 | Train Loss: 0.8104 | Test Loss: 0.9083
# Best model saved with loss: 0.8969 at 27
# Epoch 27/200 | Train Loss: 0.8005 | Test Loss: 0.8969
# Best model saved with loss: 0.8580 at 28
# Epoch 131/200 | Train Loss: 0.0449 | Test Loss: 0.0895
# Best model saved with loss: 0.0838 at 132
# Epoch 132/200 | Train Loss: 0.0419 | Test Loss: 0.0838
# Best model saved with loss: 0.0826 at 133
# Epoch 133/200 | Train Loss: 0.0427 | Test Loss: 0.0826
# Epoch 134/200 | Train Loss: 0.0417 | Test Loss: 0.0836
# Epoch 135/200 | Train Loss: 0.0423 | Test Loss: 0.0853
# Best model saved with loss: 0.0823 at 136
# Epoch 136/200 | Train Loss: 0.0403 | Test Loss: 0.0823
# Epoch 137/200 | Train Loss: 0.0400 | Test Loss: 0.0864
# Epoch 138/200 | Train Loss: 0.0427 | Test Loss: 0.0861
# Best model saved with loss: 0.0775 at 139
# Epoch 139/200 | Train Loss: 0.0391 | Test Loss: 0.0775
# Best model saved with loss: 0.0759 at 140
# Epoch 140/200 | Train Loss: 0.0405 | Test Loss: 0.0759
# Best model saved with loss: 0.0702 at 141
# Epoch 141/200 | Train Loss: 0.0359 | Test Loss: 0.0702
# Epoch 142/200 | Train Loss: 0.0369 | Test Loss: 0.0712
# Epoch 143/200 | Train Loss: 0.0367 | Test Loss: 0.0764
# Epoch 144/200 | Train Loss: 0.0317 | Test Loss: 0.0726
# Epoch 145/200 | Train Loss: 0.0344 | Test Loss: 0.0784
# Epoch 146/200 | Train Loss: 0.0354 | Test Loss: 0.0735
# Epoch 147/200 | Train Loss: 0.0336 | Test Loss: 0.0747
# Epoch 148/200 | Train Loss: 0.0305 | Test Loss: 0.0716
# Epoch 149/200 | Train Loss: 0.0329 | Test Loss: 0.0836
# Epoch 150/200 | Train Loss: 0.0333 | Test Loss: 0.0860
# Epoch 151/200 | Train Loss: 0.0306 | Test Loss: 0.0837
# Epoch 152/200 | Train Loss: 0.0292 | Test Loss: 0.0789
# Epoch 153/200 | Train Loss: 0.0291 | Test Loss: 0.0795
# Epoch 154/200 | Train Loss: 0.0267 | Test Loss: 0.0744
# Epoch 155/200 | Train Loss: 0.0273 | Test Loss: 0.0757
# Early stopping at epoch 156 with no improvement.

# %%
# Plot losses
plt.figure(figsize=(10,5))
plt.plot(model.loss_train_log, label='Train Loss')
plt.plot(model.loss_test_log, label='Test Loss')
plt.xlabel("Epoch")
plt.ylabel("CrossEntropy Loss")
plt.title("Training vs Test Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import accuracy_score

model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for xb, yb in test_loader:
        xb = xb.to(device)
        logits = model(xb)
        pred_labels = torch.argmax(logits, dim=1).cpu().numpy()
        all_preds.extend(pred_labels)
        all_labels.extend(yb.numpy())

acc = accuracy_score(all_labels, all_preds)
print(f"✅ Final Test Accuracy: {acc * 100:.2f}%")
# Out:
# ✅ Final Test Accuracy: 95.00%

# %%
raw_df = pd.read_csv("../raw.csv", header=None)       # replace with your path
X_raw = raw_df.values.astype("float32")
scaler: StandardScaler = joblib.load("scaler.joblib")
X_scaled = scaler.transform(X_raw)
X_tensor = torch.from_numpy(X_scaled)
X_tensor = X_tensor.to(device)
input_dim = X_tensor.shape[1]
model = DeepMLP(input_size=36, hidden_sizes=[256,128,64,32], output_size=8, p_dropout=0.3, device=device)
print(model.device)
model.load_state_dict(torch.load("best_model.pth", map_location="cpu"))
model.eval()

with torch.no_grad():
    logits = model(X_tensor)
    preds = torch.argmax(logits, dim=1).cpu().numpy()  # <-- move to CPU first

print(f"Predictions shape: {preds.shape}")
print(f"Predictions: {preds[:10]}")  # Print first 10 predictions
# Out:
# cuda
# Predictions shape: (4,)
# Predictions: [1 1 2 1]
